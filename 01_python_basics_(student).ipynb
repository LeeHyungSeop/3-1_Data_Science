# %% [markdown]
# # 데이터사이언스 (0010085001)
#
# ## Exercise 1: Python Basics
#
# In this excercise, we will cover basic Python
# * List, Dictionary, Function, Class

# %% [markdown]
# ### List
# A list is the Python equivalent of an array, but is resizeable and can contain elements of different types

# %%
#############################################################
# General Usage
#############################################################
xs = [3, 1, 2]

# Print the last indice
# Negative indices count from the end of the list
print(xs[-1])
# Out:
# 2

# %%
# Add a new element to the end of the list
xs.append(4)
print(xs)
# Out:
# [3, 1, 2, 4]

# %%
# Remove and return the last element of the list
x = xs.pop()
print(x, xs)
# Out:
# 4 [3, 1, 2]

# %%
#############################################################
# Slicing
#############################################################
# Create a list containing [0, 1, 2, 3, 4]
# range() is a built-in function that creates a list of integers
nums = list(range(0, 5))
print(nums)
# Out:
# [0, 1, 2, 3, 4]

# %%
# Get a slice from index 2 to 4 (exclusive); prints "[2, 3]"
print(nums[2:4])
# Out:
# [2, 3]

# %%
# Get a slice from index 2 to the end; prints "[2, 3, 4]"
print(nums[2:])
# Out:
# [2, 3, 4]

# %%
# Get a slice from the start to index 2 (exclusive); prints "[0, 1]"
print(nums[:2])
# Out:
# [0, 1]

# %%
# Get a slice of the whole list; prints ["0, 1, 2, 3, 4]"
print(nums)
# Out:
# [0, 1, 2, 3, 4]

# %%
# Assign a new sublist to a slice; change nums into [0, 1, 8, 9, 4]
sublist = [8, 9 ,4]
nums[2:] = sublist
print(nums)
# Out:
# [0, 1, 8, 9, 4]

# %%
#############################################################
# Loop & Enumerate
#############################################################
animals = ['cat', 'dog', 'monkey']

# Loop over and print the elements of the list:
for animal in animals :
    print(animal)
# Out:
# cat
# dog
# monkey

# %%
# Loop over and print the index and value of each elements of the list:

for idx, animal in enumerate(animals) :
    print(idx, animal)
# Out:
# 0 cat
# 1 dog
# 2 monkey

# %%
#############################################################
# List comprehensions
#############################################################
nums = [0, 1, 2, 3, 4]
squares = []
for x in nums:
    squares.append(x ** 2) # x ^ 2
print(squares)
# Out:
# [0, 1, 4, 9, 16]

# %%
# Make this code simpler using a list comprehension
squares = [num**2 for num in nums]
print(squares)
# Out:
# [0, 1, 4, 9, 16]

# %%
# Make a list of squares of even numbers in the list
# List comprehensions can also contain conditions
even_squares = [even**2 for even in nums if even % 2 == 0]
print(even_squares)
# Out:
# [0, 4, 16]

# %% [markdown]
# ### Dictionary
# A dictionary stores (key, value) pairs

# %%
#############################################################
# General Usage
#############################################################
# Create a dictionary containing the followings key:value pairs
# cat:cute  /  dog:furry
d = {'cat': 'cute', 'dog': 'furry'}

# %%
# print an entry 'cat' from a dictionary; prints 'cute'
print(d['cat'])
# Out:
# cute

# %%
# Add another key:value pair
# fish:wet
d["fish"] = "wet"
print(d)
# Out:
# {'cat': 'cute', 'dog': 'furry', 'fish': 'wet'}

# %%
# Get an element with a default parameter; return "N/A" if not exists
# fish / monkey
print(d.get("fish", "N/A"))
print(d.get("monkey", "N/A"))
# Out:
# wet
# N/A

# %%
# Remove 'fish' from the dictionary
d.pop('fish')
print(d)
# Out:
# {'cat': 'cute', 'dog': 'furry'}

# %% [markdown]
#  dictionary는 for loop을 돌 때, key값을 반환하게 된다.

# %%
#############################################################
# Loop & Dictionary comprehensions
#############################################################
d = {'person': 2, 'cat': 4, 'spider': 8}

# Loop over keys of the dictionary
# Access the values with the keys
for animal in d :   # dictionary는 for loop을 돌 때, key값을 반환하게 된다.
    legs = d[animal]
    print('A %s has %d legs' % (animal, legs))
# Out:
# A person has 2 legs
# A cat has 4 legs
# A spider has 8 legs

# %%
# Loop over keys and values of the dictionary
for animal, legs in d.items() : 
    print('A %s has %d legs' % (animal, legs))
# Out:
# A person has 2 legs
# A cat has 4 legs
# A spider has 8 legs

# %%
# Make a dictionary of key:squares of even numbers in the list
# Dictionary comprehensions can also contain conditions
nums = [0, 1, 2, 3, 4]
even_num_to_square = {x : x ** 2 for x in nums if x % 2 == 0}
print(even_num_to_square)
# Out:
# {0: 0, 2: 4, 4: 16}

# %% [markdown]
# ### Function
# Python functions are defined using the `def` keyword

# %%
#############################################################
# General Usage
#############################################################
# Define a function called sign() with argument x
# return 'positive' if x > 0
# return 'negative' if x < 0
# return 'zero' if x = 0
def sign(x) :
    if x > 0 :
        return "positive"
    elif x < 0 : 
        return "negative"
    else :
        return "zero"


for x in [-1, 0, 1]:
    print(sign(x))
# Out:
# negative
# zero
# positive

# %%
#############################################################
# Optional keyword argument
#############################################################
# Define a function called hello()
# argument: name
# optional argument: loud (with default value False)
# print "HELLO, [name in large letter]" if loud = True
# print "HELLO, [name in given form]" if loud = False
def hello(name, loud=False) :
    if loud == True :  
        print("HELLO, %s" % name.upper())
    else :
        print("HELLO, %s" % name)
        
hello('Bob')
hello('Fred', loud=True)
# Out:
# HELLO, Bob
# HELLO, FRED

# %% [markdown]
# ### Class
# Python classes are defined using the `class` keyword
#
# In `class` exercise, we aim to understand the class attributes such as class variable, instance variable, and inheritance.
#
# Following class diagram indicates the classes and objects, we want to implement.
#
# ![image.png](data:image/png;base64,...)

# %%
#############################################################
# Unit class
#############################################################
# Define Unit class with c
# Unit class has name, hp, speed as instance variables
# Unit class has move and damanged as class functions
# move function outputs the message with name, location, speed.
# damaged function reduces the hp when it called and outputs the message when it's hp is smaller than 0

class Unit:
    def __init__(self, name, hp, speed):
        




    def move(self, location):



    def damaged(self, damage): # AttackUnit 에서 Unit 으로 이동

# %%
#############################################################
# AttackUnit class
#############################################################
# Define AttackUnit class that inherits the Unit class
# Define damage as a instance variable
# Define attack class function which tasks location as parameter and print name, location, and damage

class AttackUnit(Unit):
    def __init__(self, name, hp, speed, damage):
        


    def attack(self, location):

# %% [markdown]
# Marine
# * hp: 40, speed: 1, attack: 5
# * stimpack: reduce hp by 10
#
# ![image.png](data:image/png;base64,...)

# %%
#############################################################
# Marine class
#############################################################
# Define Marine class that inherits the AttackUnit class
# Define stimpack class function that contains conditional statement
# Marine is able to use stimpack when hp is greater than 10

class Marine(AttackUnit):
    def __init__(self):
        

    # 스팀팩 : 일정 시간 동안 이동 및 공격 속도를 증가, 체력 10 감소
    def stimpack(self):

# %% [markdown]
# Tank
#
# * hp: 150, speed 1, attack: 35
# * siege mode: double attack power
#
# ![image.png](data:image/png;base64,...)

# %%
#############################################################
# Tank class
#############################################################
# Define Tank class that inherits the AttackUnit class
# Define siege_developed class variable that indicates whether the siege mode is developed or not (default: False)
# Define seige_mode as instance variable 
# Define set_seige_mode class function that changes the mode where seige mode doubles the damage. 
# (If the seige mode is not developed, escape the set_seige_mode function)

class Tank(AttackUnit):
    

    # 시즈모드
    def set_siege_mode(self):
    

        # 현재 시즈모드가 아닐 때
        if self.siege_mode == False:
    


        # 현재 시즈모드일 때
        else:

# %%
#############################################################
# Flyable class
#############################################################
# Define Flyable class
# Define flying_speed as a instance variable
# Define fly as class function that takes name and location as parameters and print name, location, and flying_speed

class Flyable:
    def __init__(self, flying_speed):


    def fly(self, name, location):

# %%
#############################################################
# FlyableAttackUnit class
#############################################################
# Define FlyableAttackUnit class that inherits the AttackUnit and Flyable classes
# Define move class function which tasks location as parameter and prints it

class FlyableAttackUnit(AttackUnit, Flyable):
    def __init__(self, name, hp, damage, flying_speed):
        
        
        
    def move(self, location):

# %% [markdown]
# Wraith
# * hp: 80, attack: 20, speed 5
# * clocking mode
#
# ![image.png](data:image/png;base64,...)

# %%
#############################################################
# Wraith class
#############################################################
# Define Wraith class that inherits the FlyableAttackUnit class
# Define cloaked as class variable that indicates the state of Wraith (default: False)
# Define cloaking class function that changes the state of unit

class Wraith(FlyableAttackUnit):
    def __init__(self):



    # 클로킹 모드
    def cloaking(self):
        # 현재 클로킹 모드일 때
        if self.cloaked == True:


        # 현재 클로킹 모드가 아닐 때
        else:
